# %%
#set alpha
#initialise w with random numbers
#set E to a large value (Emax)
#iter = 0 
#Repeat for until E < Emax or iter < maxIter
#  E = 0
#  for all training patterns {(x, d)}
     # output y = Wx
     # w = w + alpha*(d-y)*x

# %%
import numpy as np 
import matplotlib.pyplot as plt
import random

# %%
#weight_vector = np.zeros(3)
#w = np.array([0.1, 0.1, 0.1]) #25 weights

# %%
error_grp = []
iter_grp = []
#initialise the training patterns
training = [[np.array([-0.5, 1.2, -0.1]).transpose(), 0.2], [np.array([0.7, -0.5, -0.2]).transpose(), -0.8], [np.array([0.3, 1.2, 2.3]).transpose(), 0.8], 
            [np.array([1.2, 0.8, 1.0]).transpose(), 0.4], [np.array([-0.5, 1.2, -0.1]).transpose(), -0.2],
            [np.array([1.0, -0.3, 0.5]).transpose(), -0.1]]

# %%
def lms(w): 
  i = 0
  alpha = [0.1, 0.01, 0.001]
  Emax = 10000000000000000000000000
  maxIter = 500
  E = 0
  while ((i < maxIter) and (E < Emax)):
    E = 0
    for pair in training:
      y = np.dot(w.transpose(), pair[0])
      #print('y: ')
      #print(y)
      #print('==================')
      w = w + np.dot((alpha[2]*(pair[1] - y)), pair[0])
      #print('weight: ' + str(w))
      E = E + np.power((pair[1] - y), 2)
      #print('Error: ' + str(E))
    #Put the error in the array after going thru the whole training pattern
    error_grp.append(E)
    iter_grp.append(i)
    i = i + 1
  #print('i: ' + str(i))

  print('Final error: ' + str(E))
  print('final weight: ' + str(w))

# %%
w = []
for x in range(25):
  for y in range(3):
    val = round(random.random(), 1)
    print(val)
    w.append(val)
  weight_vector = np.array(w)
  print('Weight vector: ' + str(weight_vector))
  lms(weight_vector)
  w = []
# Out:
# 0.9
# 0.1
# 1.0
# Weight vector: [0.9 0.1 1. ]
# Final error: 0.5884608431355947
# final weight: [-0.02623224  0.11653474  0.30356919]
# 0.1
# 0.3
# 0.7
# Weight vector: [0.1 0.3 0.7]
# Final error: 0.48998563306658005
# final weight: [-0.1723616   0.0880226   0.36755863]
# 0.5
# 0.8
# 0.8
# Weight vector: [0.5 0.8 0.8]
# Final error: 0.6473132522744692
# final weight: [0.00447946 0.23233364 0.21297693]
# 0.5
# 1.0
# 0.0
# Weight vector: [0.5 1.  0. ]
# Final error: 1.0483460595665255
# final weight: [0.19824576 0.42206833 0.01105425]
# 0.1
# 0.7
# 0.2
# Weight vector: [0.1 0.7 0.2]
# Final error: 0.6657122713549812
# final weight: [-0.00835018  0.26193283  0.18988313]
# 0.4
# 0.3
# 0.4
# Weight vector: [0.4 0.3 0.4]
# Final error: 0.6051370994418024
# final weight: [-0.02204061  0.19088825  0.24471057]
# 0.4
# 0.1
# 0.1
# Weight vector: [0.4 0.1 0.1]
# Final error: 0.6386320297990161
# final weight: [0.00771427 0.20671272 0.22046339]
# 0.1
# 0.6
# 1.0
# Weight vector: [0.1 0.6 1. ]
# Final error: 0.4865787299003076
# final weight: [-0.18651376  0.0923167   0.37308806]
# 0.8
# 0.9
# 0.4
# Weight vector: [0.8 0.9 0.4]
# Final error: 0.9716972708879219
# final weight: [0.19072328 0.37400505 0.05085023]
# 0.6
# 0.1
# 0.4
# Weight vector: [0.6 0.1 0.4]
# Final error: 0.6266771803691881
# final weight: [0.00632773 0.18185384 0.24136917]
# 0.3
# 0.3
# 0.7
# Weight vector: [0.3 0.3 0.7]
# Final error: 0.5213035853931637
# final weight: [-0.11278782  0.11922531  0.32678172]
# 0.1
# 0.2
# 0.8
# Weight vector: [0.1 0.2 0.8]
# Final error: 0.4767386156914101
# final weight: [-0.20828443  0.04921684  0.40683728]
# 0.9
# 0.6
# 0.6
# Weight vector: [0.9 0.6 0.6]
# Final error: 0.8209200136828225
# final weight: [0.13306179 0.29187633 0.12773683]
# 0.0
# 1.0
# 0.1
# Weight vector: [0.  1.  0.1]
# Final error: 0.761520656985699
# final weight: [0.0289912  0.32537435 0.13355742]
# 0.2
# 0.3
# 0.7
# Weight vector: [0.2 0.3 0.7]
# Final error: 0.5039069902018944
# final weight: [-0.14257471  0.10362395  0.34717017]
# 0.0
# 0.3
# 0.8
# Weight vector: [0.  0.3 0.8]
# Final error: 0.4736556310459041
# final weight: [-0.2224686   0.05373405  0.40850798]
# 0.9
# 0.8
# 0.1
# Weight vector: [0.9 0.8 0.1]
# Final error: 1.1432026718889619
# final weight: [ 0.26586777  0.42554943 -0.01250316]
# 0.7
# 0.6
# 0.8
# Weight vector: [0.7 0.6 0.8]
# Final error: 0.6668939631274504
# final weight: [0.0328478  0.22329923 0.20963553]
# 0.9
# 0.6
# 0.2
# Weight vector: [0.9 0.6 0.2]
# Final error: 0.9979369803068124
# final weight: [0.21434222 0.36662511 0.04549324]
# 0.5
# 0.4
# 1.0
# Weight vector: [0.5 0.4 1. ]
# Final error: 0.5286055921085472
# final weight: [-0.09857164  0.114485    0.32896974]
# 0.6
# 0.4
# 0.6
# Weight vector: [0.6 0.4 0.6]
# Final error: 0.6398797725751691
# final weight: [0.01249568 0.20483514 0.2263377 ]
# 0.8
# 0.5
# 0.1
# Weight vector: [0.8 0.5 0.1]
# Final error: 0.9466346113210843
# final weight: [0.18927272 0.34959239 0.06403855]
# 0.1
# 0.8
# 0.9
# Weight vector: [0.1 0.8 0.9]
# Final error: 0.5227531894961599
# final weight: [-0.13498821  0.15124102  0.31509165]
# 0.7
# 0.1
# 0.8
# Weight vector: [0.7 0.1 0.8]
# Final error: 0.5700435784717814
# final weight: [-0.04516581  0.12270641  0.3032243 ]
# 0.6
# 0.7
# 0.9
# Weight vector: [0.6 0.7 0.9]
# Final error: 0.628380485349286
# final weight: [-0.00165648  0.20912924  0.23186713]

# %%
#Draw the graph
plt.plot(iter_grp, error_grp)
plt.ylabel('Error')
plt.xlabel('No. of iterations')
plt.show()
